# %%
# %pip install openai
# Out:
# Collecting openai
#   Downloading openai-2.1.0-py3-none-any.whl (964 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 964.9/964.9 kB 16.6 MB/s eta 0:00:00a 0:00:01
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 12.8 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 10.8 MB/s eta 0:00:00
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.11.0-cp311-cp311-macosx_11_0_arm64.whl (317 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.7/317.7 kB 25.7 MB/s eta 0:00:00
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.11.10-py3-none-any.whl (444 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 31.3 MB/s eta 0:00:00
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm>4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.6 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.4 MB/s eta 0:00:00a 0:00:01
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, sniffio, pydantic-core, jiter, h11, distro, annotated-types, pydantic, httpcore, anyio, httpx, openai
# Successfully installed annotated-types-0.7.0 anyio-4.11.0 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.11.0 openai-2.1.0 pydantic-2.11.10 pydantic-core-2.33.2 sniffio-1.3.1 typing-inspection-0.4.2
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY=os.getenv("OPEN_ROUTER_API_KEY")

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=API_KEY,
)

completion = client.chat.completions.create(
  extra_body={},
  model="openai/gpt-oss-20b:free",
  messages=[
    {
      "role": "user",
      "content": "What is the meaning of life?"
    }
  ]
)
print(completion.choices[0].message.content)
# Out:
# The question “What is the meaning of life?” has been asked for millennia, and there is no single answer that satisfies everyone.  Instead, most people arrive at a sense of meaning through a combination of **external context** and **internal experience**. Below is a broad outline of the major ways we can think about this question, followed by some practical ways to explore what it means for you personally.
#
# ---
#
# ## 1. The Big Picture Frameworks
#
# | Perspective | Core Idea | Typical Answers |
# |-------------|-----------|-----------------|
# | **Religion & Spirituality** | Human life is part of a divine plan or spiritual journey. | To fulfill a God‑commanded purpose, achieve enlightenment, live morally, die for a higher calling. |
# | **Science & Evolution** | Life arises from physical and biological processes; meaning is not built into nature. | Meaning is a human construct—product of social, psychological, and evolutionary functions such as cooperation, reproduction, and problem solving. |
# | **Philosophy** | We must create meaning through reason, choice, or authenticity. | Existentialists say life’s inherent lack of meaning is a canvas; we paint it ourselves. Pragmatists see meaning as the best practical use of our life’s resources. |
# | **Psychology** | Meaning comes from fulfillment, relationships, and self‑actualization. | Happiness, mastery, connectedness, growth, and purpose are key components. |
# | **Literature / Art** | A story, narrative, or aesthetic experience gives frame. | Life is a narrative that we continuously write; meaning emerges through storytelling, art, or collective myths. |
#
# ---
#
# ## 2. Common Themes that Cut Across Views
#
# | Theme | What it means | How to cultivate it |
# |-------|----------------|---------------------|
# | **Connection** | We are social creatures; relationships give us context. | Build deep friendships, family ties, communities, or volunteer networks. |
# | **Growth & Purpose** | Giving direction to our efforts, whether personal or for others. | Set goals, learn new skills, pursue a passion, mentor others. |
# | **Contribution** | Leaving something that benefits others or the world. | Through employment, activism, art, or small everyday acts of kindness. |
# | **Authenticity** | Living in alignment with one’s values, not merely external expectations. | Reflect on what you truly value, practice self‑awareness, make bold choices. |
# | **Resilience & Purposeful Suffering** | Making meaning out of hard times. | Therapy, journaling, meaning‑making practices like logotherapy. |
# | **Existential Freedom** | Embrace the fact that you are free to choose. | Accept responsibility, choose meaning rather than conform to pre‑made answers. |
#
# ---
#
# ## 3. Practical Ways to Find or Create Meaning
#
# 1. **Reflective Journaling**
#    Write about moments when you felt truly alive, accounted for your values, or achieved something worthwhile. Look for patterns.
#
# 2. **Narrative Reconstruction**
#    Tell your life story to someone else (or to yourself). See which chapters feel most meaningful, why, and try to amplify those narratives.
#
# 3. **Experimentally Set Goals**
#    Pick very small, concrete goals that resonate with you (e.g., learn a new recipe, finish a book, help a neighbor). Measure how they affect your emotional state.
#
# 4. **Practice Gratitude / Awe**
#    Regularly acknowledge what you are grateful for; this can shift perspective from “I just exist” to “I am part of a web of values.”
#
# 5. **Practice Mindful Presence**
#    Engage fully in daily activities; find the “micro‑meaning” in otherwise routine tasks.
#
# 6. **Explore Different Perspectives**
#    Read philosophical texts, hear religious teachings, watch science documentaries, listen to life stories from different cultures.
#
# 7. **Volunteer or Engage in Meaningful Work**
#    Activity that benefits others often returns a strong feeling of purpose, even if the work itself is not your “ultimate” passion.
#
# 8. **Seek Community**
#    Surround yourself with people who explore the question too. Life is richer when it’s tackled in dialogue.
#
# ---
#
# ## 4. Common Pitfalls
#
# | Pitfall | Why it hurts | How to avoid |
# |---------|--------------|--------------|
# | **Blind Submission** | Relying on external authority to give meaning without personal validation. | Ask: “Does this align with my sense of self?” |
# | **Idealizing “Purpose”** | Expecting an instant revelation; frustration ensues if it never arrives. | Recognize meaning as a lifelong project, not a single event. |
# | **Over‑optimization** | Multiplying tasks only for the sake of productivity, sacrificing depth. | Prioritize activities that genuinely resonate, even if they’re fewer or slower. |
# | **Neglecting Suffering** | Dismissing hardship as meaningless. | View hardships as opportunities to embed meaning through growth or service. |
#
# ---
#
# ## 5.A Quick “Good‑Morning” Takeaway
#
# > **“Meaning is the luminous thread we choose to weave through the fabric of life, crafted by our relationships, reflexes, and the small decisions we make each day.”**
#
# You need not have a panoramic answer from the start—each small act, each connection, each honest reflection compounds into a personal narrative that can feel profoundly meaningful over time.
#
# ---
#
# ### Final Thought
#
# The “meaning of life” is less a single answer hidden in a box than a **dynamic project**: an evolving constitution of relationships, commitments, and introspections that scientists, philosophers, poets, and everyday people are constantly re‑writing. Try exploring those small experiments on purpose—often the more you act, the clearer the picture of meaning becomes.
